# %%
import os
import pickle
import numpy as np

BASE_DIR = "save/setting2/mr=0.5"

metrics = {"RMSE": [], "MAE": [], "CRPS": []}

for fold in range(5):
    fold_dir = os.path.join(BASE_DIR, f"fold{fold}")
    result_file = os.path.join(fold_dir, "result_nsample100.pk")

    if not os.path.exists(result_file):
        raise FileNotFoundError(result_file)

    with open(result_file, "rb") as f:
        rmse, mae, crps = pickle.load(f)

    metrics["RMSE"].append(rmse)
    metrics["MAE"].append(mae)
    metrics["CRPS"].append(crps)

print("\nPer-fold results:")
for i in range(5):
    print(f"Fold {i}: RMSE={metrics['RMSE'][i]:.3f}, "
          f"MAE={metrics['MAE'][i]:.3f}, "
          f"CRPS={metrics['CRPS'][i]:.3f}")

print("\nMean ± SE (rounded to 3 decimals):")
for key in metrics:
    x = np.array(metrics[key], dtype=float)
    mean = x.mean()
    se = x.std(ddof=0) / np.sqrt(len(x))   # ✅ SE
    print(f"{key}: {mean:.3f} ({se:.3f})")
# Out:
# Per-fold results:
# Fold 0: RMSE=0.688, MAE=0.321, CRPS=0.350
# Fold 1: RMSE=0.588, MAE=0.318, CRPS=0.346
# Fold 2: RMSE=0.615, MAE=0.315, CRPS=0.347
# Fold 3: RMSE=0.658, MAE=0.314, CRPS=0.343
# Fold 4: RMSE=0.612, MAE=0.314, CRPS=0.344
#
# Mean ± SE (rounded to 3 decimals):
# RMSE: 0.632 (0.016)
# MAE: 0.316 (0.001)
# CRPS: 0.346 (0.001)
